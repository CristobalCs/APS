# %% [markdown]
# Primero vamos a correr los imports para la experiencia de mi TS0 OJO que esto lo puedo hacer solo una vez, entonces no hace falta correr eesta celda cada vez

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed Aug 12 23:36:49 2026

@author: cris
"""

import numpy as np
import matplotlib.pyplot as plt
print("importado") #esto se lo agrego pq asi aca en el jupyter puedo ir viendo si me imprimio bien
# Out:
# importado

# %% [markdown]
# Ahora ya podemos empezar a definir mi funcion, declarar variables y hacer los plots, lo cual cambia para cada diferente experimento que haga

# %%
def mi_funcion_sen( vmax = 1, dc = 0, ff = 1, ph=0, nn = N, fs = fs):
    
    xx = (vmax * np.sin(2 * np.pi * ff * np.arange(nn)/fs + ph)) +dc
    tt = np.arange(N)/fs
    return (tt,xx)

tt, xx = mi_funcion_sen( vmax = vmax, dc = dc, ff = ff)
print("funcion definida") #esto se lo agrego pq asi aca en el jupyter puedo ir viendo si me imprimio bien

#estas primeras son fijas de la experiencia
fs = 1000 #frecuencia fija
N = 1000 # muestras

#de aqui para abajo recien edito
vmax = 2 #simplemente mi amplitud maxima
dc = 0 # es mi desplazamiento, si es positivo me lo sube, negativo me lo baja
ff = 500 #frecuencia variable
ph = 0 #me parece q la fase ojo q es radianes!!
print("variables declaradas") #esto se lo agrego pq asi aca en el jupyter puedo ir viendo si me imprimio bien
plt.plot(tt, xx)
plt.title("señal de "+str(ff)) #esto ultimo se lo agregue porque asi los graficos me pueden ir imprimiendo bien el tema de cual frecuencia estoy imprimiendo
# Out:
# funcion definida
# variables declaradas
# Text(0.5, 1.0, 'señal de 500')

# %% [markdown]
# Ahora voy de vuelta para cada uno de los que quiero ir probando

# %%
def mi_funcion_sen( vmax = 1, dc = 0, ff = 1, ph=0, nn = N, fs = fs):
    
    xx = (vmax * np.sin(2 * np.pi * ff * np.arange(nn)/fs + ph)) +dc
    tt = np.arange(N)/fs
    return (tt,xx)

tt, xx = mi_funcion_sen( vmax = vmax, dc = dc, ff = ff)
print("funcion definida") #esto se lo agrego pq asi aca en el jupyter puedo ir viendo si me imprimio bien

#estas primeras son fijas de la experiencia
fs = 1000 #frecuencia fija
N = 1000 # muestras

#de aqui para abajo recien edito
vmax = 2 #simplemente mi amplitud maxima
dc = 0 # es mi desplazamiento, si es positivo me lo sube, negativo me lo baja
ff = 999 #frecuencia variable
ph = 0 #me parece q la fase ojo q es radianes!!
print("variables declaradas") #esto se lo agrego pq asi aca en el jupyter puedo ir viendo si me imprimio bien
plt.plot(tt, xx)
plt.title("señal de "+str(ff)) #esto ultimo se lo agregue porque asi los graficos me pueden ir imprimiendo bien el tema de cual frecuencia estoy imprimiendo
# Out:
# funcion definida
# variables declaradas
# Text(0.5, 1.0, 'señal de 999')

# %%
def mi_funcion_sen( vmax = 1, dc = 0, ff = 1, ph=0, nn = N, fs = fs):
    
    xx = (vmax * np.sin(2 * np.pi * ff * np.arange(nn)/fs + ph)) +dc
    tt = np.arange(N)/fs
    return (tt,xx)

tt, xx = mi_funcion_sen( vmax = vmax, dc = dc, ff = ff)
print("funcion definida") #esto se lo agrego pq asi aca en el jupyter puedo ir viendo si me imprimio bien

#estas primeras son fijas de la experiencia
fs = 1000 #frecuencia fija
N = 1000 # muestras

#de aqui para abajo recien edito
vmax = 2 #simplemente mi amplitud maxima
dc = 0 # es mi desplazamiento, si es positivo me lo sube, negativo me lo baja
ff = 1001 #frecuencia variable
ph = 0 #me parece q la fase ojo q es radianes!!
print("variables declaradas") #esto se lo agrego pq asi aca en el jupyter puedo ir viendo si me imprimio bien
plt.plot(tt, xx)
plt.title("señal de "+str(ff)) #esto ultimo se lo agregue porque asi los graficos me pueden ir imprimiendo bien el tema de cual frecuencia estoy imprimiendo
# Out:
# funcion definida
# variables declaradas
# Text(0.5, 1.0, 'señal de 1001')

# %%
def mi_funcion_sen( vmax = 1, dc = 0, ff = 1, ph=0, nn = N, fs = fs):
    
    xx = (vmax * np.sin(2 * np.pi * ff * np.arange(nn)/fs + ph)) +dc
    tt = np.arange(N)/fs
    return (tt,xx)

tt, xx = mi_funcion_sen( vmax = vmax, dc = dc, ff = ff)
print("funcion definida") #esto se lo agrego pq asi aca en el jupyter puedo ir viendo si me imprimio bien

#estas primeras son fijas de la experiencia
fs = 1000 #frecuencia fija
N = 1000 # muestras

#de aqui para abajo recien edito
vmax = 2 #simplemente mi amplitud maxima
dc = 0 # es mi desplazamiento, si es positivo me lo sube, negativo me lo baja
ff = 2000 #frecuencia variable
ph = 0 #me parece q la fase ojo q es radianes!!
print("variables declaradas") #esto se lo agrego pq asi aca en el jupyter puedo ir viendo si me imprimio bien
plt.plot(tt, xx)
plt.title("señal de "+str(ff)) #esto ultimo se lo agregue porque asi los graficos me pueden ir imprimiendo bien el tema de cual frecuencia estoy imprimiendo
# Out:
# funcion definida
# variables declaradas
# Text(0.5, 1.0, 'señal de 2000')

# %% [markdown]
# De aqui para abajo son cosas que fui probando para ver como cambiaban pero ya no son parte de la experiencia, pero las dejo como evidencia

# %%
fs = 1000 #frecuencia fija
N = 1000 # muestras

#de aqui para abajo recien edito
vmax = 2 #simplemente mi amplitud maxima
dc = 0 # es mi desplazamiento, si es positivo me lo sube, negativo me lo baja
ff = 499 #frecuencia variable
ph = 0 #me parece q la fase ojo q es radianes!!
ff1 = 501

def mi_funcion_sen( vmax = 1, dc = 0, ff = 1, ph=0, nn = N, fs = fs):
    
    xx = (vmax * np.sin(2 * np.pi * ff * np.arange(nn)/fs + ph)) +dc
    tt = np.arange(N)/fs
    return (tt,xx)

tt, xx = mi_funcion_sen( vmax = vmax, dc = dc, ff = ff)

plt.plot(tt, xx)



def mi_funcion_sen1( vmax = 1, dc = 0, ff1 = 1, ph=0, nn = N, fs = fs):
    
    xx1 = (vmax * np.sin(2 * np.pi * ff1 * np.arange(nn)/fs + ph)) +dc
    tt1 = np.arange(N)/fs
    return (tt1,xx1)

tt1, xx1 = mi_funcion_sen1( vmax = vmax, dc = dc, ff1 = ff1)

plt.plot(tt1, xx1)
plt.title("señal de "+str(ff)+ " vs "+str(ff1))
# Out:
# Text(0.5, 1.0, 'señal de 499 vs 501')

# %%
fs = 1000 #frecuencia fija
N = 1000 # muestras

#de aqui para abajo recien edito
vmax = 2 #simplemente mi amplitud maxima
dc = 0 # es mi desplazamiento, si es positivo me lo sube, negativo me lo baja
ff = 1 #frecuencia variable
ph = 0 #me parece q la fase ojo q es radianes!!
ff1 = 1001

def mi_funcion_sen( vmax = 1, dc = 0, ff = 1, ph=0, nn = N, fs = fs):
    
    xx = (vmax * np.sin(2 * np.pi * ff * np.arange(nn)/fs + ph)) +dc
    tt = np.arange(N)/fs
    return (tt,xx)

tt, xx = mi_funcion_sen( vmax = vmax, dc = dc, ff = ff)

plt.plot(tt, xx)



def mi_funcion_sen1( vmax = 1, dc = 0, ff1 = 1, ph=0, nn = N, fs = fs):
    
    xx1 = (vmax * np.sin(2 * np.pi * ff1 * np.arange(nn)/fs + ph)) +dc
    tt1 = np.arange(N)/fs
    return (tt1,xx1)

tt1, xx1 = mi_funcion_sen1( vmax = vmax, dc = dc, ff1 = ff1)

plt.plot(tt1, xx1)
plt.title("señal de "+str(ff)+ " vs "+str(ff1))
# Out:
# Text(0.5, 1.0, 'señal de 1 vs 1001')

# %%
fs = 1000 #frecuencia fija
N = 1000 # muestras

#de aqui para abajo recien edito
vmax = 2 #simplemente mi amplitud maxima
dc = 0 # es mi desplazamiento, si es positivo me lo sube, negativo me lo baja
ff = 1 #frecuencia variable
ph = 0 #me parece q la fase ojo q es radianes!!
ff1 = 999

def mi_funcion_sen( vmax = 1, dc = 0, ff = 1, ph=0, nn = N, fs = fs):
    
    xx = (vmax * np.sin(2 * np.pi * ff * np.arange(nn)/fs + ph)) +dc
    tt = np.arange(N)/fs
    return (tt,xx)

tt, xx = mi_funcion_sen( vmax = vmax, dc = dc, ff = ff)

plt.plot(tt, xx)



def mi_funcion_sen1( vmax = 1, dc = 0, ff1 = 1, ph=0, nn = N, fs = fs):
    
    xx1 = (vmax * np.sin(2 * np.pi * ff1 * np.arange(nn)/fs + ph)) +dc
    tt1 = np.arange(N)/fs
    return (tt1,xx1)

tt1, xx1 = mi_funcion_sen1( vmax = vmax, dc = dc, ff1 = ff1)

plt.plot(tt1, xx1)
plt.title("señal de "+str(ff)+ " vs "+str(ff1))
# Out:
# Text(0.5, 1.0, 'señal de 1 vs 999')

# %% [markdown]
# Pude comprobar con mis ultimas experimentaciones que si que se cumplia que fuera espejado pero desfasado, ahora experimentare con una cuadrada

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Thu Aug 13 00:47:06 2026

@author: cris
"""

import numpy as np
import matplotlib.pyplot as plt
from scipy import signal 

fs = 1000 #frecuencia fija
N = 1000 # muestras

#de aqui para abajo recien edito
vmax = 2 #simplemente mi amplitud maxima
dc = 0 # es mi desplazamiento, si es positivo me lo sube, negativo me lo baja
ff = 20 #frecuencia variable
ph = 0 #me parece q la fase ojo q es radianes!!

def mi_funcion_cuadrada(vmax=1, dc=0, ff=1, ph=0, nn=N, fs=fs):
    xx = (vmax * signal.square(2 * np.pi * ff * np.arange(nn)/fs + ph)) +dc
    tt = np.arange(N)/fs
    return (tt,xx)

tt, xx = mi_funcion_cuadrada( vmax = vmax, dc = dc, ff = ff)

plt.plot(tt, xx)
plt.title("señal de "+str(ff))
# Out:
# Text(0.5, 1.0, 'señal de 20')

# %%
from scipy import signal 
fs = 1000 #frecuencia fija
N = 1000 # muestras

#de aqui para abajo recien edito
vmax = 2 #simplemente mi amplitud maxima
dc = 0 # es mi desplazamiento, si es positivo me lo sube, negativo me lo baja
ff = 2 #frecuencia variable
ph = 0 #me parece q la fase ojo q es radianes!!
ff1 = 3

def mi_funcion_cuadrada(vmax=1, dc=0, ff=1, ph=0, nn=N, fs=fs):
    xx = (vmax * signal.square(2 * np.pi * ff * np.arange(nn)/fs + ph)) +dc
    tt = np.arange(N)/fs
    return (tt,xx)

tt, xx = mi_funcion_cuadrada( vmax = vmax, dc = dc, ff = ff)

plt.plot(tt, xx)

def mi_funcion_cuadrada1(vmax=1, dc=0, ff1=1, ph=0, nn=N, fs=fs):
    xx1 = (vmax * signal.square(2 * np.pi * ff1 * np.arange(nn)/fs + ph)) +dc
    tt1 = np.arange(N)/fs
    return (tt1,xx1)

tt1, xx1 = mi_funcion_cuadrada1( vmax = vmax, dc = dc, ff1 = ff1)

plt.plot(tt1, xx1)
plt.title("señal de "+str(ff)+ " vs "+str(ff1))
# Out:
# Text(0.5, 1.0, 'señal de 2 vs 3')

# %% [markdown]
# Bueno, con mi experimentacion conclui que basado en la parte teorica de la clase la frecuencia de Nyquist es la que me define hasta que punto puedo ir ampleando mi frecuencia y que siga definiendose bien, tambien vi el tema del espejeo.
